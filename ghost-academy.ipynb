# %% [markdown]
# # 🎓 Ghost Acadmia - AI-Powered Certificate Management System
#
# ## Overview
#
# **Certifier** is a cutting-edge certificate management system built with **Google Gemini AI** and deployed on **Netlify**. It leverages AI and blockchain technology to create, verify, and manage digital certificates with advanced security features including steganography and cryptographic verification.
#
# ## 🚀 Live Demos & Links
#
# | **Production Deployment** | **AI Studio Integration** | **GitHub Repository** |
# |---|---|---|
# | [🌐 View Live App](https://ghost-acedmia.netlify.app/) | [🤖 AI Studio Preview](https://aistudio.google.com/app/apps/drive/1XlFMxEOPeTwLvCJ7cUrPmAqdDxMGbYAs?showPreview=true&showAssistant=true) | [📚 GitHub Repo](https://github.com/GouravMital/GhostAcademia-Gemini) |
# | Deployed on Netlify with global CDN | Interactive preview with Google AI Studio | Source code & documentation |
#
# ## 🏗️ Tech Stack
#
# **Frontend:**
# - React 19.2.3 - Modern UI library with concurrent features
# - TypeScript 5.8.2 - Type-safe development
# - Vite 6.2.0 - Lightning-fast build tool
# - React Router DOM 7.10.1 - Client-side routing
#
# **Security & Verification:**
# - Steganography - Hidden data embedding in certificates
# - Cryptographic Verification - Secure certificate validation
# - Blockchain Integration - Smart contract-based certificate registry
#
# **Deployment:**
# - Netlify - Global CDN deployment with automatic HTTPS
#
# ## 🎯 Key Features
#
# ### 📊 Dashboard Components
# - **Issuer Dashboard** - Certificate creation and management
# - **Exam Taker Interface** - Interactive examination system
# - **Verifier Portal** - Certificate authenticity verification
# - **Navigation System** - Seamless user experience
#
# ### 🔐 Security Features
# - Digital Signatures - Cryptographic certificate validation
# - Steganographic Embedding - Hidden security markers
# - Blockchain Verification - Immutable certificate records
# - Smart Contract Integration - Automated certificate lifecycle
#
# ## 📈 Performance Metrics
#
# - **Build Time:** ~1.3 seconds
# - **Bundle Size:** 256.73 kB (81.31 kB gzipped)
# - **Loading Time:** Sub-second with Netlify CDN
# - **SEO Optimized:** Server-side rendering ready
#
# ## 🔧 Environment Setup
#
# ```
# GEMINI_API_KEY=your_api_key_here
# ```
#
# ## 📝 Getting Started
#
# ```bash
# # Clone the repository
# git clone https://github.com/GouravMital/GhostAcademia-Gemini
# cd certifier
#
# # Install dependencies
# npm install
#
# # Start development server
# npm run dev
#
# # Build for production
# npm run build
# ```
#
# ## 📁 Project Structure
#
# ```
# certifier/
# ├── components/       # React components
# │   ├── ExamTaker.tsx
# │   ├── IssuerDashboard.tsx
# │   ├── Verifier.tsx
# │   └── NavBar.tsx
# ├── contracts/        # Smart contracts
# ├── utils/            # Utility functions
# ├── types.ts          # TypeScript definitions
# └── vite.config.ts    # Build configuration
# ```
#
# ## 🤝 Contributing
#
# 1. Fork the repository
# 2. Create your feature branch (`git checkout -b feature/amazing-feature`)
# 3. Commit your changes (`git commit -m 'Add some amazing feature'`)
# 4. Push to the branch (`git push origin feature/amazing-feature`)
# 5. Open a Pull Request
#
# ## 📜 License
#
# MIT License - see LICENSE file for details
#
# ## 🙏 Acknowledgments
#
# - Google AI Studio for AI integration capabilities
# - Netlify for seamless deployment and hosting
# - React Team for the amazing React framework
# - Vite Team for the blazing-fast build tool
#
# ---
#
# **⭐ Star the repository if you find it helpful!**

# %% [markdown]
# ## 🚀 Deployment on Netlify
#
# ### Production Deployment
#
# The Certifier app is deployed on **Netlify** with:
#
# - ✅ **Global CDN** with edge locations worldwide
# - ✅ **Automatic HTTPS** and SSL certificates
# - ✅ **Continuous Deployment** from Git repository
# - ✅ **Built-in Form Handling** and serverless functions
# - ✅ **Sub-second Loading** times with optimized CDN
#
# **Live URL:** https://ghost-acedmia.netlify.app/
#
# ### How to Deploy Your Own Instance
#
# ```bash
# # Build the project
# npm run build
#
# # Deploy to Netlify
# netlify deploy --prod --dir=dist
# ```
#
# ## 💻 Built With Google Gemini AI
#
# This project showcases the power of **Google Gemini 2.5** integrated through:
#
# - **AI Studio Integration** - Interactive AI-powered features
# - **Real-time Processing** - Fast certificate generation
# - **Intelligent Verification** - AI-assisted certificate validation
# - **Natural Language Support** - Gemini's language capabilities
#
# **AI Studio Link:** [https://aistudio.google.com/app/apps/drive/1XlFMxEOPeTwLvCJ7cUrPmAqdDxMGbYAs](https://aistudio.google.com/app/apps/drive/1XlFMxEOPeTwLvCJ7cUrPmAqdDxMGbYAs)
#
# ## 🌐 Quick Demo
#
# ### Dashboard Navigation
#
# - **Home Page** - Project overview and navigation
# - **Issuer Dashboard** (`/issuer`) - Create and manage certificates
# - **Exam Taker** (`/examtaker`) - Interactive examination system
# - **Verifier** (`/verifier`) - Verify certificate authenticity
#
# ### Key Workflows
#
# 1. **Issue Certificate**
#    - Fill in certificate details
#    - Apply steganographic markers
#    - Generate cryptographic signatures
#    - Deploy to blockchain
#
# 2. **Verify Certificate**
#    - Upload or input certificate
#    - Validate digital signatures
#    - Extract hidden data
#    - Confirm blockchain record
#
# 3. **Take Exam**
#    - Access interactive exam interface
#    - Submit answers
#    - Receive instant feedback
#    - Get certificate upon completion
#
# ## 📄 README Integration
#
# All project documentation is maintained in the GitHub repository:
#
# - **GitHub Repo:** https://github.com/GouravMital/GhostAcademia-Gemini
# - **README.md** - Complete project documentation
# - **DESIGN_DOCUMENT.md** - Architecture and design details
# - **MIT License** - Open-source license
#
# ---
#
# **Last Updated:** December 2024
#
# **Made with ❤️ by Gourav Mital**
